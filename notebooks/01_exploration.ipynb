# %% [markdown]
# # Predictor Classifier Ulmm - Data Exploration
#
# This notebook contains exploratory data analysis for the ML project.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

# %%
# Load data
df = pd.read_csv('../data/sample.csv')
df.head()
